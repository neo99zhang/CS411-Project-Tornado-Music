# %%
### ugly codes ###
import time
from selenium import webdriver
import pandas
import numpy as np

# %%
from selenium.webdriver.chrome.options import Options
chrome_options =Options()
chrome_options.add_argument('--headless')

# %%
##### A crawler #####
def search_song(search_name,index):
    time_begin = time.time()
    print("index: "+str(index)+"begin searching! search name: "+search_name)
    url =  "https://odesli.co/"
    driver = webdriver.Chrome(options=chrome_options)
    driver.get(url=url)
    #driver.maximize_window()
    input = driver.find_element_by_id("search-page-downshift-input")
    input.send_keys(search_name)
    # key = driver.find_element_by_id("su")
    # key.click()
    time.sleep(2)
    # input2 = driver.find_element_by_id("search-page-downshift-item-0")
    # input2=driver.find_elements_by_css_selector('search-page-downshift-menu')
    try:
        input2 = driver.find_element_by_id("search-page-downshift-item-0")
    except:
        time.sleep(5)
        try:
            input2 = driver.find_element_by_id("search-page-downshift-item-0")
        except:
            time.sleep(15)
            input2 = driver.find_element_by_id("search-page-downshift-item-0")
    input3 = input2.find_element_by_css_selector('a')
    input4 = input3.find_elements_by_css_selector('div')
    count=0
    for element in input4:
        if count==4:
            input5 = element
    #     print(element.get_attribute('outerHTML'))
    #     print('\n')
        count+=1
    input5.get_attribute('outerHTML')
    input6_list = input5.find_elements_by_css_selector('button')
    count=0
    for element in input6_list:
        if count==1:
            element.click()
        count+=1
    all_handles = driver.window_handles
    mainWindow = driver.current_window_handle
    for handle in all_handles:
        driver.switch_to.window(handle)
        if search_name in handle:
            break
    input7 = driver.find_element_by_id("main-app-element")
    input8 = input7.find_element_by_css_selector('div')
    input9 = input8.find_element_by_css_selector('main')
    input10_list = input9.find_elements_by_css_selector('div:nth-child(2)')
    count=0
    for element in input10_list:
        if count==4:
            input11 = element
            break
    #         print(element.get_attribute('outerHTML'))
    #         print('\n')
        count+=1
    input11_text = input11.get_attribute('outerHTML')
    source_count = len(input11_text.split('href'))-1
    source_dict = {}
    source_full_dict = {}
    source_count_number_list=range(1,source_count+1)
    for i in source_count_number_list:
        input12 = input11.find_element_by_css_selector('a:nth-child('+str(i)+')')
        input12_text = input12.get_attribute('outerHTML')
        input12_url = input12_text.split(' ')[1].split('href=')[1]
        input12_source = input12_text.split('</div>')[0].split('>')[-1]
        source_dict[input12_source]=input12_url
    
    # print(input11.get_attribute('outerHTML'))

    source_full_list = ['Apple Music','Spotify','YouTube','YouTube Music','Pandora','Deezer','SoundCloud','Amazon Music','TIDAL','Napster','Yandex']
    for i in source_full_list:
        if i in source_dict:
            source_full_dict[i] = source_dict[i]
        else:
            source_full_dict[i] = 'not found'
        



    # for element in input12_list:
    #     print(element.get_attribute('outerHTML'))
    #     print('\n')
    #main-app-element > div > main > div:nth-child(2) > div.css-jnwrwc > a:nth-child(9) > div > svg > path:nth-child(2)
    #main-app-element > div > main > div:nth-child(2) > div.css-jnwrwc > a:nth-child(1)
    # driver.switch_to.window(mainWindow)
    #search-page-downshift-item-0 > a > div.css-1khvdun.euwaufo0 > button

    #main-app-element > div > main > div:nth-child(2) > div.css-jnwrwc > a:nth-child(2)

    #search-page-downshift-item-0 > a > div.css-1khvdun.euwaufo0 > button
    # key.click()

    #main-app-element > div > main > div:nth-child(2) > div.css-jnwrwc > a:nth-child(5) > div > svg > circle
    # input2= driver.find_element_by_id("search-page-downshift-label")
    # key.click()
    # time.sleep(5)
    driver.quit()
    time_end = time.time()
    print("index: "+str(index)+'finish current search, search time: '+str(time_end-time_begin))
    return source_full_dict

# %%
search_song('my love',1)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-32-8dc5e08c21f1> in <module>
# ----> 1 search_song('my love',1)
#
# <ipython-input-31-28ad30a4de6b> in search_song(search_name, index)
#       2 def search_song(search_name,index):
#       3     time_begin = time.time()
# ----> 4     print("index: "+str(i)+"begin searching! search name: "+search_name)
#       5     url =  "https://odesli.co/"
#       6     driver = webdriver.Chrome(options=chrome_options)
#
# UnboundLocalError: local variable 'i' referenced before assignment

# %%
###### load Spotify 1.2M+ Songs dataset #####
dataset_path='../dataset/tracks_features.csv'
dataset_df = pandas.read_csv(dataset_path)

# %%
print(len(dataset_df['id']))
# Out:
# 1204025

# %%
sim_dataset_df = dataset_df.drop(columns='track_number'and'disc_number'and'explicit'and'key'and'loudness'and'mode'and'speechiness'
                                 and 'acousticness' and 'instrumentalness' and 'valence' and 'tempo' and 'time_signature')

# %%
sim_dataset_df2 = sim_dataset_df.sample(6000)
sim_dataset_csv = sim_dataset_df2.to_csv('../dataset/sim_dataset_6000.csv')

# %%
sim_dataset_df2 = pandas.read_csv('../dataset/sim_dataset_6000.csv')
# sim_dataset_df2.index = pandas.Series([i for i in range(6000)])

# %%
for key in sim_dataset_df2:
    print(key)
print(len(sim_dataset_df2['id']))
# Out:
# Unnamed: 0
# id
# name
# album
# album_id
# artists
# artist_ids
# track_number
# disc_number
# explicit
# danceability
# energy
# key
# loudness
# mode
# speechiness
# acousticness
# instrumentalness
# liveness
# valence
# tempo
# duration_ms
# year
# release_date
# 6000

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
##### building music database ######
music_df = sim_dataset_df2[['id','name','artists','artist_ids','year']]
music_df.loc[:,'genre'] = 'NAN'
music_df.loc[:,'language'] = 'NAN'
#music_df.loc[:,'year'] = sim_dataset_df2[['year']]
music_df.loc[:,'country'] = 'NAN'
music_df
# Out:
#                           id  \
# 0     4dmMjskgaxqlFqx6qKEAKc
# 1     5cgAOqY99fTp8nUAirMqSC
# 2     4RsRnevj2E5PuSUNTRjo4K
# 3     1m76FKIBMEEPCLRUGLaBpu
# 4     4WiVsHCol2j8xgMG2MQr1u
# ...                      ...
# 5995  4yBj4YEverWkL56zKVjKA8
# 5996  27QujEogKqtgC9COOfAeks
# 5997  10c0Jav8AzEFALcQ4dj8hl
# 5998  44y0Y827bW9Oi4bZUHIu23
# 5999  7maQfPEQj0QiHHGI84NiYY
#
#                                                    name  \
# 0                                  Light On the Horizon
# 1                                            Windshield
# 2     Billion Dollar Babies - Live at the NEC, Birmi...
# 3                                   Riddles in the Dark
# 4                                                    Qi
# ...                                                 ...
# 5995  Team Fight Tactics - Intro (From League of Leg...
# 5996                                         San-Ho-Say
# 5997                                              Alien
# 5998                                          Dust Bowl
# 5999                                   Trance: Trance 2
#
#                                                 artists  \
# 0                                 ['Undercover Rabbis']
# 1                                    ['Astronaut Wife']
# 2                                      ['Alice Cooper']
# 3                                      ['Howard Shore']
# 4                                     ['Karlla Naynna']
# ...                                                 ...
# 5995                              ['League of Legends']
# 5996                                      ['Magic Sam']
# 5997                                    ['Light Drive']
# 5998                                           ['Tami']
# 5999  ['Michael Gordon', 'Julian Brewer', 'Brendan B...
#
#                                              artist_ids  year genre language  \
# 0                            ['3HiraY0HCogjMLjRDR0IqI']  2012   NAN      NAN
# 1                            ['1eQEMu3xpy3MTPWL9mbmbd']  2005   NAN      NAN
# 2                            ['3EhbVgyfGd7HkpsagwL9GS']  2018   NAN      NAN
# 3                            ['0OcclcP5o8VKH2TRqSY2A7']  2012   NAN      NAN
# 4                            ['2ag8WmKNLXFUnI7koFuFOh']  2018   NAN      NAN
# ...                                                 ...   ...   ...      ...
# 5995                         ['47mIJdHORyRerp4os813jD']  2019   NAN      NAN
# 5996                         ['0XErJwG6aCEj7NpKsEZrrO']  1990   NAN      NAN
# 5997                         ['7HbSd4VOhzXN87lxM8koCb']  2014   NAN      NAN
# 5998                         ['61TIWELeKl26hh2QCucVVk']  2018   NAN      NAN
# 5999  ['69Qu66Y6G07dk23Ld2ym1F', '2D6khBdQqcq7jeJd0A...  2004   NAN      NAN
#
#      country
# 0        NAN
# 1        NAN
# 2        NAN
# 3        NAN
# 4        NAN
# ...      ...
# 5995     NAN
# 5996     NAN
# 5997     NAN
# 5998     NAN
# 5999     NAN
#
# [6000 rows x 8 columns]

# %%
##### building album database ######
album_df = sim_dataset_df2[['album_id','album','year']]
album_df
# Out:
#                     album_id  \
# 0     7wOPHOw5GKUK7bFXwlBN4q
# 1     3ovRPg2FDFx1Hwpo8zycks
# 2     52f7wJGh6N37n92m3Bvv2Z
# 3     6X0qkUUcolJDrRN3i3CAlT
# 4     5xT5h1ZF1g8E0vdVXTZXOp
# ...                      ...
# 5995  3cYnSSnBe1akJwxv64PHOg
# 5996  6KUrpcJMp9uJqdOSL9CgrC
# 5997  0OGTeVA6GWI7LH178xbDFf
# 5998  5RdQOl5SSkF6DsEFhnNNcH
# 5999  4UUXYqhXmi7klTG9bH6oZR
#
#                                                   album  year
# 0                                               Empires  2012
# 1                                         Flying Saucer  2005
# 2           The Essential Alice Cooper - The Epic Years  2018
# 3     The Hobbit: An Unexpected Journey (Original Mo...  2012
# 4                                              Soberana  2018
# ...                                                 ...   ...
# 5995  The Music of League of Legends: Season 9 (Orig...  2019
# 5996                                     Magic Sam Live  1990
# 5997                                              Alien  2014
# 5998                                     Velvet & Steel  2018
# 5999                                             Trance  2004
#
# [6000 rows x 3 columns]

# %%
##### building artist database ######
artist_df = sim_dataset_df2[['artists','artist_ids']]
artist_df.loc[:,'age'] = 'NAN'
artist_df.loc[:,'description'] = 'NAN'
artist_df.loc[:,'country'] = 'NAN'
artist_df.loc[:,'gender'] = 'NAN'
artist_df.loc[:,'awards'] = 'NAN'
artist_df
# Out:
#                                                 artists  \
# 0                                 ['Undercover Rabbis']
# 1                                    ['Astronaut Wife']
# 2                                      ['Alice Cooper']
# 3                                      ['Howard Shore']
# 4                                     ['Karlla Naynna']
# ...                                                 ...
# 5995                              ['League of Legends']
# 5996                                      ['Magic Sam']
# 5997                                    ['Light Drive']
# 5998                                           ['Tami']
# 5999  ['Michael Gordon', 'Julian Brewer', 'Brendan B...
#
#                                              artist_ids  age description  \
# 0                            ['3HiraY0HCogjMLjRDR0IqI']  NAN         NAN
# 1                            ['1eQEMu3xpy3MTPWL9mbmbd']  NAN         NAN
# 2                            ['3EhbVgyfGd7HkpsagwL9GS']  NAN         NAN
# 3                            ['0OcclcP5o8VKH2TRqSY2A7']  NAN         NAN
# 4                            ['2ag8WmKNLXFUnI7koFuFOh']  NAN         NAN
# ...                                                 ...  ...         ...
# 5995                         ['47mIJdHORyRerp4os813jD']  NAN         NAN
# 5996                         ['0XErJwG6aCEj7NpKsEZrrO']  NAN         NAN
# 5997                         ['7HbSd4VOhzXN87lxM8koCb']  NAN         NAN
# 5998                         ['61TIWELeKl26hh2QCucVVk']  NAN         NAN
# 5999  ['69Qu66Y6G07dk23Ld2ym1F', '2D6khBdQqcq7jeJd0A...  NAN         NAN
#
#      country gender awards
# 0        NAN    NAN    NAN
# 1        NAN    NAN    NAN
# 2        NAN    NAN    NAN
# 3        NAN    NAN    NAN
# 4        NAN    NAN    NAN
# ...      ...    ...    ...
# 5995     NAN    NAN    NAN
# 5996     NAN    NAN    NAN
# 5997     NAN    NAN    NAN
# 5998     NAN    NAN    NAN
# 5999     NAN    NAN    NAN
#
# [6000 rows x 7 columns]

# %%
##### building tag database ######
##### not sure

# %%
##### change index ######
df = sim_dataset_df2
df.index = pandas.Series([i for i in range(6000)])
df
# Out:
#       Unnamed: 0                      id  \
# 0         320753  4dmMjskgaxqlFqx6qKEAKc
# 1         281433  5cgAOqY99fTp8nUAirMqSC
# 2         761846  4RsRnevj2E5PuSUNTRjo4K
# 3         337279  1m76FKIBMEEPCLRUGLaBpu
# 4         974619  4WiVsHCol2j8xgMG2MQr1u
# ...          ...                     ...
# 5995      940554  4yBj4YEverWkL56zKVjKA8
# 5996        1049  27QujEogKqtgC9COOfAeks
# 5997      475686  10c0Jav8AzEFALcQ4dj8hl
# 5998     1127433  44y0Y827bW9Oi4bZUHIu23
# 5999      839017  7maQfPEQj0QiHHGI84NiYY
#
#                                                    name  \
# 0                                  Light On the Horizon
# 1                                            Windshield
# 2     Billion Dollar Babies - Live at the NEC, Birmi...
# 3                                   Riddles in the Dark
# 4                                                    Qi
# ...                                                 ...
# 5995  Team Fight Tactics - Intro (From League of Leg...
# 5996                                         San-Ho-Say
# 5997                                              Alien
# 5998                                          Dust Bowl
# 5999                                   Trance: Trance 2
#
#                                                   album  \
# 0                                               Empires
# 1                                         Flying Saucer
# 2           The Essential Alice Cooper - The Epic Years
# 3     The Hobbit: An Unexpected Journey (Original Mo...
# 4                                              Soberana
# ...                                                 ...
# 5995  The Music of League of Legends: Season 9 (Orig...
# 5996                                     Magic Sam Live
# 5997                                              Alien
# 5998                                     Velvet & Steel
# 5999                                             Trance
#
#                     album_id  \
# 0     7wOPHOw5GKUK7bFXwlBN4q
# 1     3ovRPg2FDFx1Hwpo8zycks
# 2     52f7wJGh6N37n92m3Bvv2Z
# 3     6X0qkUUcolJDrRN3i3CAlT
# 4     5xT5h1ZF1g8E0vdVXTZXOp
# ...                      ...
# 5995  3cYnSSnBe1akJwxv64PHOg
# 5996  6KUrpcJMp9uJqdOSL9CgrC
# 5997  0OGTeVA6GWI7LH178xbDFf
# 5998  5RdQOl5SSkF6DsEFhnNNcH
# 5999  4UUXYqhXmi7klTG9bH6oZR
#
#                                                 artists  \
# 0                                 ['Undercover Rabbis']
# 1                                    ['Astronaut Wife']
# 2                                      ['Alice Cooper']
# 3                                      ['Howard Shore']
# 4                                     ['Karlla Naynna']
# ...                                                 ...
# 5995                              ['League of Legends']
# 5996                                      ['Magic Sam']
# 5997                                    ['Light Drive']
# 5998                                           ['Tami']
# 5999  ['Michael Gordon', 'Julian Brewer', 'Brendan B...
#
#                                              artist_ids  track_number  \
# 0                            ['3HiraY0HCogjMLjRDR0IqI']             5
# 1                            ['1eQEMu3xpy3MTPWL9mbmbd']            10
# 2                            ['3EhbVgyfGd7HkpsagwL9GS']            15
# 3                            ['0OcclcP5o8VKH2TRqSY2A7']             8
# 4                            ['2ag8WmKNLXFUnI7koFuFOh']            45
# ...                                                 ...           ...
# 5995                         ['47mIJdHORyRerp4os813jD']            14
# 5996                         ['0XErJwG6aCEj7NpKsEZrrO']            10
# 5997                         ['7HbSd4VOhzXN87lxM8koCb']             1
# 5998                         ['61TIWELeKl26hh2QCucVVk']             2
# 5999  ['69Qu66Y6G07dk23Ld2ym1F', '2D6khBdQqcq7jeJd0A...             2
#
#       disc_number  explicit  ...  mode  speechiness  acousticness  \
# 0               1     False  ...     1       0.0407      0.001840
# 1               1     False  ...     0       0.0452      0.243000
# 2               2     False  ...     0       0.0950      0.000491
# 3               2     False  ...     0       0.0390      0.579000
# 4               1     False  ...     1       0.3100      0.092700
# ...           ...       ...  ...   ...          ...           ...
# 5995            1     False  ...     1       0.0379      0.983000
# 5996            1     False  ...     0       0.0452      0.119000
# 5997            1     False  ...     1       0.0387      0.000442
# 5998            1     False  ...     1       0.0407      0.342000
# 5999            1     False  ...     1       0.1570      0.467000
#
#       instrumentalness  liveness  valence    tempo  duration_ms  year  \
# 0             0.303000    0.0989   0.2410   61.250       643408  2012
# 1             0.000000    0.0829   0.7360   89.966       261453  2005
# 2             0.299000    0.6040   0.0961   94.632       217733  2018
# 3             0.926000    0.0688   0.0340  110.079       321758  2012
# 4             0.007060    0.0736   0.7350  130.054       184599  2018
# ...                ...       ...      ...      ...          ...   ...
# 5995          0.873000    0.1470   0.0353   78.700        52000  2019
# 5996          0.841000    0.8810   0.9010  143.235       196200  1990
# 5997          0.002390    0.0819   0.3120  119.967       232000  2014
# 5998          0.000232    0.1020   0.5900   86.055       240920  2018
# 5999          0.898000    0.2420   0.3690   64.978       409773  2004
#
#       release_date
# 0       2012-09-10
# 1       2005-10-05
# 2       2018-03-16
# 3       2012-12-11
# 4       2018-10-21
# ...            ...
# 5995    2019-10-15
# 5996    1990-01-01
# 5997    2014-02-27
# 5998    2018-10-12
# 5999          2004
#
# [6000 rows x 24 columns]

# %%
##### building link database ######
## search list ##
df_search_list = df[['id','name','artists']]
name_list = df_search_list['name']
artists_list = df_search_list['artists']
search_list = []
for i in range(6000):
    search_list.append(name_list[i]+' '+artists_list[i].split("'")[1])
df_search_list
# Out:
#                           id  \
# 0     4dmMjskgaxqlFqx6qKEAKc
# 1     5cgAOqY99fTp8nUAirMqSC
# 2     4RsRnevj2E5PuSUNTRjo4K
# 3     1m76FKIBMEEPCLRUGLaBpu
# 4     4WiVsHCol2j8xgMG2MQr1u
# ...                      ...
# 5995  4yBj4YEverWkL56zKVjKA8
# 5996  27QujEogKqtgC9COOfAeks
# 5997  10c0Jav8AzEFALcQ4dj8hl
# 5998  44y0Y827bW9Oi4bZUHIu23
# 5999  7maQfPEQj0QiHHGI84NiYY
#
#                                                    name  \
# 0                                  Light On the Horizon
# 1                                            Windshield
# 2     Billion Dollar Babies - Live at the NEC, Birmi...
# 3                                   Riddles in the Dark
# 4                                                    Qi
# ...                                                 ...
# 5995  Team Fight Tactics - Intro (From League of Leg...
# 5996                                         San-Ho-Say
# 5997                                              Alien
# 5998                                          Dust Bowl
# 5999                                   Trance: Trance 2
#
#                                                 artists
# 0                                 ['Undercover Rabbis']
# 1                                    ['Astronaut Wife']
# 2                                      ['Alice Cooper']
# 3                                      ['Howard Shore']
# 4                                     ['Karlla Naynna']
# ...                                                 ...
# 5995                              ['League of Legends']
# 5996                                      ['Magic Sam']
# 5997                                    ['Light Drive']
# 5998                                           ['Tami']
# 5999  ['Michael Gordon', 'Julian Brewer', 'Brendan B...
#
# [6000 rows x 3 columns]

# %%
music_df.loc[:,'AppleMusicLink']=''
music_df.loc[:,'SpotifyLink']=''
music_df.loc[:,'YouTubeLink']=''
music_df.loc[:,'YouTubeMusicLink']=''
music_df.loc[:,'PandoraLink']=''
music_df.loc[:,'DeezerLink']=''
music_df.loc[:,'SoundCloudLink']=''
music_df.loc[:,'AmazonMusicLink']=''
music_df.loc[:,'TIDALLink']=''
music_df.loc[:,'NapsterLink']=''
music_df.loc[:,'YandexLink']=''

# %%
music_df
# Out:
#                           id  \
# 0     4dmMjskgaxqlFqx6qKEAKc
# 1     5cgAOqY99fTp8nUAirMqSC
# 2     4RsRnevj2E5PuSUNTRjo4K
# 3     1m76FKIBMEEPCLRUGLaBpu
# 4     4WiVsHCol2j8xgMG2MQr1u
# ...                      ...
# 5995  4yBj4YEverWkL56zKVjKA8
# 5996  27QujEogKqtgC9COOfAeks
# 5997  10c0Jav8AzEFALcQ4dj8hl
# 5998  44y0Y827bW9Oi4bZUHIu23
# 5999  7maQfPEQj0QiHHGI84NiYY
#
#                                                    name  \
# 0                                  Light On the Horizon
# 1                                            Windshield
# 2     Billion Dollar Babies - Live at the NEC, Birmi...
# 3                                   Riddles in the Dark
# 4                                                    Qi
# ...                                                 ...
# 5995  Team Fight Tactics - Intro (From League of Leg...
# 5996                                         San-Ho-Say
# 5997                                              Alien
# 5998                                          Dust Bowl
# 5999                                   Trance: Trance 2
#
#                                                 artists  \
# 0                                 ['Undercover Rabbis']
# 1                                    ['Astronaut Wife']
# 2                                      ['Alice Cooper']
# 3                                      ['Howard Shore']
# 4                                     ['Karlla Naynna']
# ...                                                 ...
# 5995                              ['League of Legends']
# 5996                                      ['Magic Sam']
# 5997                                    ['Light Drive']
# 5998                                           ['Tami']
# 5999  ['Michael Gordon', 'Julian Brewer', 'Brendan B...
#
#                                              artist_ids  year genre language  \
# 0                            ['3HiraY0HCogjMLjRDR0IqI']  2012   NAN      NAN
# 1                            ['1eQEMu3xpy3MTPWL9mbmbd']  2005   NAN      NAN
# 2                            ['3EhbVgyfGd7HkpsagwL9GS']  2018   NAN      NAN
# 3                            ['0OcclcP5o8VKH2TRqSY2A7']  2012   NAN      NAN
# 4                            ['2ag8WmKNLXFUnI7koFuFOh']  2018   NAN      NAN
# ...                                                 ...   ...   ...      ...
# 5995                         ['47mIJdHORyRerp4os813jD']  2019   NAN      NAN
# 5996                         ['0XErJwG6aCEj7NpKsEZrrO']  1990   NAN      NAN
# 5997                         ['7HbSd4VOhzXN87lxM8koCb']  2014   NAN      NAN
# 5998                         ['61TIWELeKl26hh2QCucVVk']  2018   NAN      NAN
# 5999  ['69Qu66Y6G07dk23Ld2ym1F', '2D6khBdQqcq7jeJd0A...  2004   NAN      NAN
#
#      country AppleMusicLink SpotifyLink YouTubeLink YouTubeMusicLink  \
# 0        NAN
# 1        NAN
# 2        NAN
# 3        NAN
# 4        NAN
# ...      ...            ...         ...         ...              ...
# 5995     NAN
# 5996     NAN
# 5997     NAN
# 5998     NAN
# 5999     NAN
#
#      PandoraLink DeezerLink SoundCloudLink AmazonMusicLink TIDALLink  \
# 0
# 1
# 2
# 3
# 4
# ...          ...        ...            ...             ...       ...
# 5995
# 5996
# 5997
# 5998
# 5999
#
#      NapsterLink YandexLink
# 0
# 1
# 2
# 3
# 4
# ...          ...        ...
# 5995
# 5996
# 5997
# 5998
# 5999
#
# [6000 rows x 19 columns]

# %%
# begin search #
link_list=[]
time_start = time.time()
for i in range(1000):
    found_flag = 'true'
    try:
        current_link_dict = search_song(search_list[i],i)
    except:
        print("Oops! Link not found within 20s")
        found_flag = 'false'
    if found_flag == 'true':
        music_df.loc[i,'AppleMusicLink']=current_link_dict['Apple Music']
        music_df.loc[i,'SpotifyLink']=current_link_dict['Spotify']
        music_df.loc[i,'YouTubeLink']=current_link_dict['YouTube']
        music_df.loc[i,'YouTubeMusicLink']=current_link_dict['YouTube Music']
        music_df.loc[i,'PandoraLink']=current_link_dict['Pandora']
        music_df.loc[i,'DeezerLink']=current_link_dict['Deezer']
        music_df.loc[i,'SoundCloudLink']=current_link_dict['SoundCloud']
        music_df.loc[i,'AmazonMusicLink']=current_link_dict['Amazon Music']
        music_df.loc[i,'TIDALLink']=current_link_dict['TIDAL']
        music_df.loc[i,'NapsterLink']=current_link_dict['Napster']
        music_df.loc[i,'YandexLink']=current_link_dict['Yandex']
    else:
        music_df.loc[i,'AppleMusicLink']='not found'
        music_df.loc[i,'SpotifyLink']='not found'
        music_df.loc[i,'YouTubeLink']='not found'
        music_df.loc[i,'YouTubeMusicLink']='not found'
        music_df.loc[i,'PandoraLink']='not found'
        music_df.loc[i,'DeezerLink']='not found'
        music_df.loc[i,'SoundCloudLink']='not found'
        music_df.loc[i,'AmazonMusicLink']='not found'
        music_df.loc[i,'TIDALLink']='not found'
        music_df.loc[i,'NapsterLink']='not found'
        music_df.loc[i,'YandexLink']='not found'
    if(i%10==0):
        music_df.to_csv("music_database.csv")
time_end = time.time()
print("Final finish search! time is "+str(time_end-time_start))
# Out:
# begin searching! search name: Light On the Horizon Undercover Rabbis
# finish current search, search time: 5.0584716796875
# begin searching! search name: Windshield Astronaut Wife
# finish current search, search time: 7.6246116161346436
# Final finish search! time is 12.706824779510498

# %%
search
# Out:
#                           id  \
# 0     4Ix0uoIbp9jvpO3OXPwYZu
# 1     4hUZZwS0LYPntArz1Hfbud
# 2     2Bo1UUG0kIzX4T7Xgsuh8d
# 3     3nBQIVtlmjuwqoLMP8cRHQ
# 4     0sDYCsr5idKyPiwunsu9jR
# ...                      ...
# 5995  2fJrXbtjKn8DgPLCosLYFJ
# 5996  09k0nXk66mu6yxSwaqjSBP
# 5997  7JBAbcTwUmIdvFOAsx0D4t
# 5998  3mHI82rXE6dqbHOSmbYzmi
# 5999  2hHme5mT8WsawBjkiYsZ55
#
#                                                    name  \
# 0         STAR TREK BORG: Resistance is Futile, My Ass!
# 1                                     Tristes Tropiques
# 2                                      Proof Of Concept
# 3                                                Facies
# 4                Christmas In Dixie - with spoken outro
# ...                                                 ...
# 5995                                 Steel Guitar Blues
# 5996  Swanwhite, JS 189, Act II: Act II: Lento: Styv...
# 5997                                               Wish
# 5998                                      Change For Me
# 5999                                Mountain Rose Waltz
#
#                                                 artists  \
# 0                                    ['Dominik Hauser']
# 1                                   ['Hopeful Monster']
# 2                                  ['3D House Of Beef']
# 3                                            ['Matter']
# 4                                           ['Alabama']
# ...                                                 ...
# 5995                                      ['Roy Acuff']
# 5996  ['Jean Sibelius', 'Turku Philharmonic Orchestr...
# 5997                                     ['Anna Calvi']
# 5998                                  ['Eric Roberson']
# 5999                            ['The Gothard Sisters']
#
#                                              artist_ids  year genre language  \
# 0                            ['4MTfVjZzx72caVcbCjUK73']  2013   NAN      NAN
# 1                            ['2bgDRcIDYeyIdPZo4eaHLV']  2002   NAN      NAN
# 2                            ['4UvQ1BHgClXG8RZKtFpmx6']  2001   NAN      NAN
# 3                            ['2vNupCaLWRRH9Q707HmvjB']  2018   NAN      NAN
# 4                            ['6rJqqRce0Kvo2dJUXoHleC']  1980   NAN      NAN
# ...                                                 ...   ...   ...      ...
# 5995                         ['7heUyuJw3gZftFZRa1rV6M']  1936   NAN      NAN
# 5996  ['7jzR5qj8vFnSu5JHaXgFEr', '2yJX6ev7Io4KagCeNd...  2015   NAN      NAN
# 5997                         ['50sSN9E5i4DJzYDclAXlSo']  2018   NAN      NAN
# 5998                         ['2ewAU3d4El7WSIxWUJaZJn']  2003   NAN      NAN
# 5999                         ['6wtQsVMMzaKcK3hUEI1C1X']  2015   NAN      NAN
#
#      country                                     AppleMusicLink  \
# 0        NAN  "https://geo.music.apple.com/us/album/_/101710...
# 1        NAN  "https://geo.music.apple.com/us/album/_/278030...
# 2        NAN
# 3        NAN
# 4        NAN
# ...      ...                                                ...
# 5995     NAN
# 5996     NAN
# 5997     NAN
# 5998     NAN
# 5999     NAN
#
#                                             SpotifyLink  \
# 0     "https://open.spotify.com/track/4mBdX1MT5kq9Nb...
# 1     "https://open.spotify.com/track/4hUZZwS0LYPntA...
# 2
# 3
# 4
# ...                                                 ...
# 5995
# 5996
# 5997
# 5998
# 5999
#
#                                         YouTubeLink  \
# 0     "https://www.youtube.com/watch?v=oSgPiXRIl_Q"
# 1     "https://www.youtube.com/watch?v=9orVJgJPSq0"
# 2
# 3
# 4
# ...                                             ...
# 5995
# 5996
# 5997
# 5998
# 5999
#
#                                      YouTubeMusicLink PandoraLink  \
# 0     "https://music.youtube.com/watch?v=oSgPiXRIl_Q"   not found
# 1     "https://music.youtube.com/watch?v=9orVJgJPSq0"   not found
# 2
# 3
# 4
# ...                                               ...         ...
# 5995
# 5996
# 5997
# 5998
# 5999
#
#                                    DeezerLink SoundCloudLink  \
# 0     "https://www.deezer.com/track/68184822"      not found
# 1     "https://www.deezer.com/track/83518974"      not found
# 2
# 3
# 4
# ...                                       ...            ...
# 5995
# 5996
# 5997
# 5998
# 5999
#
#                                         AmazonMusicLink  \
# 0     "https://music.amazon.com/albums/B0152NML7Y?tr...
# 1     "https://music.amazon.com/albums/B0019J86BG?tr...
# 2
# 3
# 4
# ...                                                 ...
# 5995
# 5996
# 5997
# 5998
# 5999
#
#                                       TIDALLink  \
# 0     "https://listen.tidal.com/track/48744517"
# 1                                     not found
# 2
# 3
# 4
# ...                                         ...
# 5995
# 5996
# 5997
# 5998
# 5999
#
#                                     NapsterLink  \
# 0     "https://napster.com/track/tra.192006834"
# 1      "https://napster.com/track/tra.24556378"
# 2
# 3
# 4
# ...                                         ...
# 5995
# 5996
# 5997
# 5998
# 5999
#
#                                     YandexLink
# 0     "https://music.yandex.ru/track/47073202"
# 1     "https://music.yandex.ru/track/22605815"
# 2
# 3
# 4
# ...                                        ...
# 5995
# 5996
# 5997
# 5998
# 5999
#
# [6000 rows x 19 columns]

# %%
k={'Apple Music': '"https://geo.music.apple.com/us/album/_/303099932?i=303099937&amp;mt=1&amp;app=music&amp;ls=1&amp;at=1000lHKX"',
 'Spotify': '"https://open.spotify.com/track/2rXovB7Zco7nc3nTHXKJoh"',
 'YouTube': '"https://www.youtube.com/watch?v=d1w1Vzf7IZk"',
 'YouTube Music': '"https://music.youtube.com/watch?v=d1w1Vzf7IZk"',
 'Pandora': '"https://www.pandora.com/TR:7221013"',
 'Deezer': '"https://www.deezer.com/track/13144409"',
 'SoundCloud': 'not found',
 'Amazon Music': '"https://music.amazon.com/albums/B001BKAQI4?trackAsin=B001BKGOXU&amp;do=play"',
 'TIDAL': '"https://listen.tidal.com/track/3296683"',
 'Napster': '"https://napster.com/track/tra.12057340"',
 'Yandex': 'not found'}
for i in k:
    #print(i.replace(' ','')+'Link')
    print(i)
# Out:
# Apple Music
# Spotify
# YouTube
# YouTube Music
# Pandora
# Deezer
# SoundCloud
# Amazon Music
# TIDAL
# Napster
# Yandex

# %%
# #### building the billboard dataset ####
# import billboard
# year_list=range(2006,2021)
# song_name_list = []
# musician_list = []
# search_list = []
# def get_song_from_year(year):
#     chart = billboard.ChartData('alternative-songs',year=2006)
#     for i in range(len(chart)):
#         song = chart[i]
#         song_name = str(song).split("'")[1]
#         musician = str(song).split("'")[2].split('by ')[-1]
#         song_name_list.append(song_name)
#         musician_list.append(musician)
#         search_list.append(song_name+' '+musician) 

# for year in year_list:
#     get_song_from_year(year)

# %%
# output_dict={}
# for i in range(len(search_list)):
#     try:
#         search_song(search_list[i],song_name_list[i],musician_list[i])
#     except:
#         time.sleep(10)
#         search_song(search_list[i],song_name_list[i],musician_list[i])

# %%
# print(output_dict)
